# %%
# importing the necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
 
hea_ds=pd.read_csv("health.csv")
hea_ds.head()
# Out:
#    Patient_ID  Health_Camp_ID  Donation  Health_Score  Unnamed: 4
# 0      506181            6560        40      0.439024         NaN
# 1      494977            6560        20      0.097561         NaN
# 2      518680            6560        10      0.048780         NaN
# 3      509916            6560        30      0.634146         NaN
# 4      488006            6560        20      0.024390         NaN

# %%
hea_ds=hea_ds.dropna(axis=1)

# %%
import numpy as np

hea_ds['patient_status']=np.array(['Good' if i>=0.5 else 'Bad' for i in hea_ds['Health_Score'] ])
hea_ds
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score patient_status
# 0         506181            6560        40      0.439024            Bad
# 1         494977            6560        20      0.097561            Bad
# 2         518680            6560        10      0.048780            Bad
# 3         509916            6560        30      0.634146           Good
# 4         488006            6560        20      0.024390            Bad
# ...          ...             ...       ...           ...            ...
# 6213      502728            6575        10      0.509804           Good
# 6214      511088            6575        20      0.078431            Bad
# 6215      507608            6575        40      0.627451           Good
# 6216      488046            6575        50      0.686275           Good
# 6217      508766            6575        50      0.921569           Good
#
# [6218 rows x 5 columns]

# %%
for i in hea_ds:
    k=sum(hea_ds[i].isnull())
    print(i,":",k)
# Out:
# Patient_ID : 0
# Health_Camp_ID : 0
# Donation : 0
# Health_Score : 0
# patient_status : 0

# %%
import seaborn as sns
import plotly.express as px
# Tree map for the 
ax=px.treemap(hea_ds,path=['Health_Camp_ID'],
              title='Camp Wise Patients')
ax.show()
# Out:
# <div>                            <div id="140b10d3-e2a8-4aa6-9044-7e23eb5adf28" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("140b10d3-e2a8-4aa6-9044-7e23eb5adf28")) {                    Plotly.newPlot(                        "140b10d3-e2a8-4aa6-9044-7e23eb5adf28",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003ecount=%{value}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["6524","6526","6530","6531","6532","6535","6537","6538","6539","6540","6542","6543","6544","6546","6552","6553","6554","6557","6558","6560","6561","6562","6563","6564","6565","6569","6570","6571","6575","6580","6581","6585","6586","6587"],"lab
# ...

# %%
camp_patient_count = hea_ds.groupby('Health_Camp_ID')['Patient_ID'].count().reset_index()
# Create a bar chart
fig = px.bar(hea_ds, 
             x='Health_Camp_ID', 
             y='Patient_ID', 
             title='Number of Patients from Each Health Camp',
             labels={'Health_Camp_ID': 'Health Camp ID', 'Patient_ID': 'Number of Patients'},
            color_discrete_sequence=['blue'])
fig.show()
# Out:
# <div>                            <div id="1749b029-bcd9-4784-9900-00e03c7b2a31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1749b029-bcd9-4784-9900-00e03c7b2a31")) {                    Plotly.newPlot(                        "1749b029-bcd9-4784-9900-00e03c7b2a31",                        [{"alignmentgroup":"True","hovertemplate":"Health Camp ID=%{x}\u003cbr\u003eNumber of Patients=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"blue","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6530,6530,6530,6530,6530,6530,
# ...

# %%
total_patients = hea_ds['Patient_ID'].nunique()
total_health_camps = hea_ds['Health_Camp_ID'].nunique()
# Creating a bar chart
data = {'Category': ['Total Patients', 'Total Health Camps'],
        'Count': [total_patients, total_health_camps]}
fig = px.bar(data, x='Category', y='Count', text='Count', title='Total Patients and Health Camps')
# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="6d8a62ce-33be-473d-a3b4-36f06404cd55" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d8a62ce-33be-473d-a3b4-36f06404cd55")) {                    Plotly.newPlot(                        "6d8a62ce-33be-473d-a3b4-36f06404cd55",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}\u003cbr\u003eCount=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3548.0,34.0],"textposition":"auto","x":["Total Patients","Total Health Camps"],"xaxis":"x","y":[3548,34],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"t
# ...

# %%
fig = px.pie(hea_ds, names='Donation', title='Distribution of Donations from Patients')
# Show the pie chart
fig.show()
# Out:
# <div>                            <div id="d23d4b5b-d5d5-4a6c-924f-2d48962cf67e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d23d4b5b-d5d5-4a6c-924f-2d48962cf67e")) {                    Plotly.newPlot(                        "d23d4b5b-d5d5-4a6c-924f-2d48962cf67e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Donation=%{label}\u003cextra\u003e\u003c\u002fextra\u003e","labels":[40,20,10,30,20,40,30,30,20,30,50,30,40,20,70,20,30,30,20,20,50,50,20,30,50,20,10,30,30,10,20,10,10,20,10,10,10,30,10,20,10,10,10,20,20,30,10,20,30,20,20,10,40,30,20,30,30,20,10,30,50,40,50,30,50,20,30,10,110,40,40,130,20,70,50,70,50,30,30,20,80,30,70,80,40,50,20,30,50,60,80,90,10,20,40,40,10,90,30,20,40,30,30,50,60,20,40,30,50,110,70,30,60
# ...

# %%
hea_ds['Discahrge']=np.array([1 if i=='Good' else 0 for i in hea_ds['patient_status'] ])
hea_ds
# Out:
#       Patient_ID  Health_Camp_ID  Donation  Health_Score patient_status  \
# 0         506181            6560        40      0.439024            Bad
# 1         494977            6560        20      0.097561            Bad
# 2         518680            6560        10      0.048780            Bad
# 3         509916            6560        30      0.634146           Good
# 4         488006            6560        20      0.024390            Bad
# ...          ...             ...       ...           ...            ...
# 6213      502728            6575        10      0.509804           Good
# 6214      511088            6575        20      0.078431            Bad
# 6215      507608            6575        40      0.627451           Good
# 6216      488046            6575        50      0.686275           Good
# 6217      508766            6575        50      0.921569           Good
#
#       Discahrge
# 0             0
# 1             0
# 2             0
# 3             1
# ...

# %%
fig = px.box(hea_ds, x='patient_status', y='Health_Score', title='Distribution of Health Scores')
fig.show()
# Out:
# <div>                            <div id="66b2d265-de02-4bb4-9001-5eba254eea49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66b2d265-de02-4bb4-9001-5eba254eea49")) {                    Plotly.newPlot(                        "66b2d265-de02-4bb4-9001-5eba254eea49",                        [{"alignmentgroup":"True","hovertemplate":"patient_status=%{x}\u003cbr\u003eHealth_Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["Bad","Bad","Bad","Good","Bad","Good","Good","Bad","Bad","Good","Good","Good","Good","Bad","Good","Good","Bad","Good","Bad","Bad","Good","Good","Bad","Good","Good","Good","Bad","Bad","Bad","Good","Bad",
# ...

# %%
fig = px.scatter(hea_ds, x='Donation', y='Health_Score', color='patient_status', title='Donation vs. Health Score')
fig.show()
# Out:
# <div>                            <div id="b08fe6d6-bd67-40cf-ad69-148cee473246" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b08fe6d6-bd67-40cf-ad69-148cee473246")) {                    Plotly.newPlot(                        "b08fe6d6-bd67-40cf-ad69-148cee473246",                        [{"hovertemplate":"patient_status=Bad\u003cbr\u003eDonation=%{x}\u003cbr\u003eHealth_Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bad","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Bad","showlegend":true,"x":[40,20,10,20,30,20,20,30,20,20,20,10,30,30,20,10,10,10,20,20,20,10,40,30,20,10,30,40,30,20,30,10,70,70,50,30,30,30,40,20,30,10,20,10,30,40,30,30,50,20,30,10,20,10,70,50,10,30,20,50,20,50,20,20,10,40,30,40,30,30,1
# ...

# %%
fig = px.line(hea_ds, x='Health_Camp_ID', y='Health_Score', color='patient_status', 
              title='Health Score Trends Over Health Camps')
fig.show()
# Out:
# <div>                            <div id="399b882a-310c-4c5c-b5d6-768ac030dfba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("399b882a-310c-4c5c-b5d6-768ac030dfba")) {                    Plotly.newPlot(                        "399b882a-310c-4c5c-b5d6-768ac030dfba",                        [{"hovertemplate":"patient_status=Bad\u003cbr\u003eHealth_Camp_ID=%{x}\u003cbr\u003eHealth_Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bad","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Bad","showlegend":true,"x":[6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6560,6530,6530,6530,6530,6530,6530,6530,6530,6530,6530,6530,6530,6544,6544,6544,6544,6585,6585,6585,6585,6585,6585,6585,658
# ...

# %%
patient_status_count = hea_ds['patient_status'].value_counts().reset_index()
# Creating a bar chart
fig = px.bar(patient_status_count, x='index', y='patient_status', text='patient_status', 
             title='Number of Patients Categorized as Good and Bad',
             labels={'index': 'Patient Status', 'patient_status': 'Number of Patients'})
# Show the bar chart
fig.show()
# Out:
# <div>                            <div id="b4350f94-df15-4fe5-8c35-8fb757c5204a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4350f94-df15-4fe5-8c35-8fb757c5204a")) {                    Plotly.newPlot(                        "b4350f94-df15-4fe5-8c35-8fb757c5204a",                        [{"alignmentgroup":"True","hovertemplate":"Patient Status=%{x}\u003cbr\u003eNumber of Patients=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[3261.0,2957.0],"textposition":"auto","x":["Good","Bad"],"xaxis":"x","y":[3261,2957],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"typ
# ...
